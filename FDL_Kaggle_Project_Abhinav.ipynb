# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhinavSingh6295/Deep_Learning-Project/blob/main/FDL_Kaggle_Project_Abhinav.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import glob 
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive = drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_images = '/content/drive/MyDrive/FoundationDeepLearning_Labs/Kaggle_Project/train_images/train_images/'
train_masks = '/content/drive/MyDrive/FoundationDeepLearning_Labs/Kaggle_Project/train_masks/train_masks/'
test_images = '/content/drive/MyDrive/FoundationDeepLearning_Labs/Kaggle_Project/test_images/test_images/'

# %%
X_train = sorted(glob.glob(train_images + '*.jpg'))
y_train = sorted(glob.glob(train_masks + '*.png'))
X_test = glob.glob(test_images+'*.jpg')

print(len(X_train))
print(len(y_train))
print(len(X_test))
# Out:
# 261
# 261
# 112

# %%
#Random image/mask pair from training set

idx = np.random.choice(range(len(X_train)))
img = Image.open(X_train[20])
msk = Image.open(y_train[20])

print(img.size)
print(msk.size)

plt.imshow(img.resize((512, 512)))
plt.imshow(msk.resize((512, 512)), alpha = 0.5)

plt.show()
# Out:
# (3000, 4000)
# (3000, 4000)
